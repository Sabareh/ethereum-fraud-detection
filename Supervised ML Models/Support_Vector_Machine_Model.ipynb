# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import accuracy_score, f1_score

# %%
df = pd.read_csv('../Data/address_data_combined.csv')
df.head()
# Out:
#                                       Address  FLAG  Avg min between sent tnx  \
# 0  0x87d884aaa6ff9e9b6014631b0abae80b53953fb8     1                   5151.68
# 1  0xd42393df90d582bd8a5493171f0173e3a017d391     1                   1179.02
# 2  0x3025c36d8a9620d3df89e9e9b1acbdfd639a6f37     1                    361.73
# 3  0x6309f709faad518fc158af4c14edfa7b06424770     1                      0.00
# 4  0x3d020954e30c3d40b7f0c533cf198bc10dd45a49     1                  14280.60
#
#    Avg min between received tnx  Time Diff between first and last (Mins)  \
# 0                      15159.08                                 71235.62
# 1                       1124.89                                 25126.45
# 2                          0.00                                   723.47
# 3                          0.00                                     0.00
# 4                       1479.86                                 45357.57
#
#    Unique Received From Addresses  min value received  max value received   \
# 0                               1            0.010000             0.020000
# 1                              13            0.000000             0.750000
# 2                               1            4.999916             4.999916
# 3                               0            0.000000             0.000000
# 4                              21            0.035000             0.200000
#
#    avg val received  min val sent  avg val sent  \
# 0          0.013367      0.000000      0.000000
# 1          0.176667      0.145000      0.419270
# 2          4.999916      2.490000      2.499538
# 3          0.000000      0.000000      0.000000
# 4          0.099286      2.084658      2.084658
#
#    total transactions (including tnx to create contract  total ether received  \
# 0                                                  8                 0.040100
# 1                                                 22                 2.650000
# 2                                                  3                 4.999916
# 3                                                  0                 0.000000
# 4                                                 22                 2.085000
#
#    total ether balance
# 0             0.040100
# 1            -0.284889
# 2             0.000840
# 3             0.000000
# 4             0.000342

# %%
X = df.drop(columns=['Address','FLAG'])
y = df['FLAG']
print(X.shape)
print(y.shape)
# Out:
# (14155, 12)
# (14155,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42,test_size=0.3,stratify=y)

print(X_train.shape)
print(X_test.shape)
# Out:
# (9908, 12)
# (4247, 12)

# %%
import numpy as np

columns = ['Avg min between sent tnx', 'Avg min between received tnx',
       'Time Diff between first and last (Mins)',
       'Unique Received From Addresses', 'min value received',
       'max value received ', 'avg val received', 'min val sent',
       'avg val sent', 'total transactions (including tnx to create contract',
       'total ether received', 'total ether balance']
    
scaler = MinMaxScaler()

# Log for Skewed Data
for c in columns:
  X_train[c] = X_train[c].apply(lambda x: np.log(x) if x > 0 else 0)
  X_test[c] = X_test[c].apply(lambda x: np.log(x) if x > 0 else 0)

# Scaling
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

np.isnan(X_train)
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
tuned_parameters = [
    { "gamma": [1,0.1,0.01,0.001], "C": [1, 10, 100, 1000]},
]

grid = GridSearchCV(SVC(kernel='linear'),tuned_parameters, refit=True,verbose=2,cv=5, scoring='f1')
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] END .......................................C=1, gamma=1; total time=   4.2s
# [CV] END .......................................C=1, gamma=1; total time=   7.5s
# [CV] END .......................................C=1, gamma=1; total time=   5.2s
# [CV] END .......................................C=1, gamma=1; total time=   2.2s
# [CV] END .......................................C=1, gamma=1; total time=   3.1s
# [CV] END .....................................C=1, gamma=0.1; total time=   2.3s
# [CV] END .....................................C=1, gamma=0.1; total time=   2.7s
# [CV] END .....................................C=1, gamma=0.1; total time=   3.7s
# [CV] END .....................................C=1, gamma=0.1; total time=   3.6s
# [CV] END .....................................C=1, gamma=0.1; total time=   6.4s
# [CV] END ....................................C=1, gamma=0.01; total time=   3.6s
# [CV] END ....................................C=1, gamma=0.01; total time=   3.0s
# [CV] END ....................................C=1, gamma=0.01; total time=   2.0s
# [CV] END ....................................C=1, gamma=0.01; total time=   3.3s
# [CV] END ....................................C=1, gamma=0.01; total time=   7.8s
# [CV] END ...................................C=1, gamma=0.001; total time=  10.6s
# [CV] END ...................................C=1, gamma=0.001; total time=   7.5s
# [CV] END ...................................C=1, gamma=0.001; total time=   4.2s
# [CV] END ...................................C=1, gamma=0.001; total time=   6.7s
# [CV] END ...................................C=1, gamma=0.001; total time=   8.5s
# [CV] END ......................................C=10, gamma=1; total time=   7.1s
# [CV] END ......................................C=10, gamma=1; total time=   9.5s
# [CV] END ......................................C=10, gamma=1; total time=   4.1s
# [CV] END ......................................C=10, gamma=1; total time=   5.1s
# [CV] END ......................................C=10, gamma=1; total time=   6.9s
# [CV] END ....................................C=10, gamma=0.1; total time=   8.6s
# [CV] END ....................................C=10, gamma=0.1; total time=   7.7s
# [CV] END ....................................C=10, gamma=0.1; total time=   7.7s
# [CV] END ....................................C=10, gamma=0.1; total time=   5.6s
# [CV] END ....................................C=10, gamma=0.1; total time=   5.9s
# [CV] END ...................................C=10, gamma=0.01; total time=   5.2s
# [CV] END ...................................C=10, gamma=0.01; total time=   5.9s
# [CV] END ...................................C=10, gamma=0.01; total time=   4.2s
# [CV] END ...................................C=10, gamma=0.01; total time=   4.3s
# [CV] END ...................................C=10, gamma=0.01; total time=   3.9s
# [CV] END ..................................C=10, gamma=0.001; total time=   2.7s
# [CV] END ..................................C=10, gamma=0.001; total time=   2.4s
# [CV] END ..................................C=10, gamma=0.001; total time=   2.5s
# [CV] END ..................................C=10, gamma=0.001; total time=   3.2s
# [CV] END ..................................C=10, gamma=0.001; total time=   4.1s
# [CV] END .....................................C=100, gamma=1; total time=   8.5s
# [CV] END .....................................C=100, gamma=1; total time=  10.0s
# [CV] END .....................................C=100, gamma=1; total time=   6.5s
# [CV] END .....................................C=100, gamma=1; total time=   7.4s
# [CV] END .....................................C=100, gamma=1; total time=   6.4s
# [CV] END ...................................C=100, gamma=0.1; total time=  13.3s
# [CV] END ...................................C=100, gamma=0.1; total time=  10.3s
# [CV] END ...................................C=100, gamma=0.1; total time=   9.4s
# [CV] END ...................................C=100, gamma=0.1; total time=   7.8s
# [CV] END ...................................C=100, gamma=0.1; total time=   9.4s
# [CV] END ..................................C=100, gamma=0.01; total time=  11.0s
# [CV] END ..................................C=100, gamma=0.01; total time=  16.4s
# [CV] END ..................................C=100, gamma=0.01; total time=  28.0s
# [CV] END ..................................C=100, gamma=0.01; total time=  20.0s
# [CV] END ..................................C=100, gamma=0.01; total time=  14.4s
# [CV] END .................................C=100, gamma=0.001; total time=  11.2s
# [CV] END .................................C=100, gamma=0.001; total time=  16.1s
# [CV] END .................................C=100, gamma=0.001; total time=  13.2s
# [CV] END .................................C=100, gamma=0.001; total time=  12.3s
# [CV] END .................................C=100, gamma=0.001; total time=  11.5s
# [CV] END ....................................C=1000, gamma=1; total time=  53.4s
# [CV] END ....................................C=1000, gamma=1; total time=  35.7s
# [CV] END ....................................C=1000, gamma=1; total time=  25.3s
# [CV] END ....................................C=1000, gamma=1; total time=  28.7s
# [CV] END ....................................C=1000, gamma=1; total time=  22.2s
# [CV] END ..................................C=1000, gamma=0.1; total time=  34.7s
# [CV] END ..................................C=1000, gamma=0.1; total time=  25.4s
# [CV] END ..................................C=1000, gamma=0.1; total time=  25.2s
# [CV] END ..................................C=1000, gamma=0.1; total time=  28.4s
# [CV] END ..................................C=1000, gamma=0.1; total time=  24.5s
# [CV] END .................................C=1000, gamma=0.01; total time=  22.1s
# [CV] END .................................C=1000, gamma=0.01; total time=  23.8s
# [CV] END .................................C=1000, gamma=0.01; total time=  26.1s
# [CV] END .................................C=1000, gamma=0.01; total time=  32.2s
# [CV] END .................................C=1000, gamma=0.01; total time=  22.4s
# [CV] END ................................C=1000, gamma=0.001; total time=  22.2s
# [CV] END ................................C=1000, gamma=0.001; total time=  22.8s
# [CV] END ................................C=1000, gamma=0.001; total time=  26.9s
# [CV] END ................................C=1000, gamma=0.001; total time=  27.5s
# [CV] END ................................C=1000, gamma=0.001; total time=  22.7s
# GridSearchCV(cv=5, estimator=SVC(kernel='linear'),
#              param_grid=[{'C': [1, 10, 100, 1000],
#                           'gamma': [1, 0.1, 0.01, 0.001]}],
#              scoring='f1', verbose=2)

# %%
grid.best_params_
# Out:
# {'C': 1000, 'gamma': 1}

# %%
grid.best_score_
# Out:
# 0.8465308950971894

# %%
from sklearn.metrics import accuracy_score
predicted_y_acc = grid.predict(X_test)
predicted_y_acc = (predicted_y_acc > 0.5).astype('int32')
accuracy_score(predicted_y_acc, y_test)
# Out:
# 0.8613138686131386

# %%
print("Tuned Hyperparameters :", grid.best_params_)
print("Train F1 Score :",grid.best_score_)
best_y_pr = grid.predict(X_test)
print('Test F1 Score: ', f1_score(y_test, best_y_pr))
# Out:
# Tuned Hyperparameters : {'C': 1000, 'gamma': 1}
# Train F1 Score : 0.8465308950971894
# Test F1 Score:  0.8486250321254176

# %%
from matplotlib import pyplot as plt
feat_importances = grid.best_estimator_.coef_[0]
indices = np.argsort(feat_importances)
# plot
fig, ax = plt.subplots(figsize=(10, 6))
plt.title("Ranked feature importances")
plt.barh(range(len(feat_importances)), feat_importances[indices], align="center")
features = ['feature_{}'.format(columns[i]) for i in range(len(columns))]
plt.yticks(range(len(feat_importances)), [features[idx] for idx in indices])
plt.ylim([-1, len(feat_importances)])
plt.show();
# Out:
# Matplotlib is building the font cache; this may take a moment.
